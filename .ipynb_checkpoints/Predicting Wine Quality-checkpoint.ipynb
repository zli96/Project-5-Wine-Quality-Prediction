# %% [markdown]
# # Predicting wine quality

# %% [markdown]
# This [kaggle dataset](https://www.kaggle.com/rajyellow46/wine-quality) is originally found in the [UCI Machine Learning repository](https://archive.ics.uci.edu/ml/datasets/Wine+Quality). Similar to the wine dataset that comes with sklearn, this dataset is also about wine but the goal is to predict the quality of the wine as a integer score ranging from 1 to 10. A summary of the dataset is shown below. One thing to notice is that the dataset is quite unbalanced in terms of quality, the feature we want to predict. As we can see that the mean of the column is about 5.8 with a standard deviation of 0.87, which means the majority of the wine sampled have a mediocore quality and only a small percentage of the samples are considered as either good or poor.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sn
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.metrics import confusion_matrix
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense

data_df = read_csv('winequalityN.csv')
data_df.describe(include = 'all')
# print(data_df.columns)
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497    6487.000000       6489.000000  6494.000000     6495.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4898            NaN               NaN          NaN             NaN
# mean      NaN       7.216579          0.339691     0.318722        5.444326
# std       NaN       1.296750          0.164649     0.145265        4.758125
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.400000     0.390000        8.100000
# max       NaN      15.900000          1.580000     1.660000       65.800000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count   6495.000000          6497.000000           6497.000000  6497.000000
# unique          NaN                  NaN                   NaN          NaN
# top             NaN                  NaN                   NaN          NaN
# freq            NaN                  NaN                   NaN          NaN
# mean       0.056042            30.525319            115.744574     0.994697
# std        0.035036            17.749400             56.521855     0.002999
# min        0.009000             1.000000              6.000000     0.987110
# 25%        0.038000            17.000000             77.000000     0.992340
# 50%        0.047000            29.000000            118.000000     0.994890
# 75%        0.065000            41.000000            156.000000     0.996990
# max        0.611000           289.000000            440.000000     1.038980
#
#                  pH    sulphates      alcohol      quality
# count   6488.000000  6493.000000  6497.000000  6497.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       3.218395     0.531215    10.491801     5.818378
# std        0.160748     0.148814     1.192712     0.873255
# min        2.720000     0.220000     8.000000     3.000000
# 25%        3.110000     0.430000     9.500000     5.000000
# 50%        3.210000     0.510000    10.300000     6.000000
# 75%        3.320000     0.600000    11.300000     6.000000
# max        4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# There are missing data in quite a few features including fixed acidity, volatile acidity, residual sugar, chlorides, pH, and sulphates. The percentage of the missing value takes in whole sample size is very small. However, since the dataset is unbalanced, these missing values could potentially have a big impact on the prediction if they happend to correspond to the outlier classes.

# %% [markdown]
# In this example I used the mean imputing method to fill in the missing data. This method

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy="mean")
featuresWithMissing = ["fixed acidity", "volatile acidity","citric acid", "residual sugar", "chlorides", "pH", "sulphates"]
imputer = imputer.fit(data_df[featuresWithMissing])
data_df[featuresWithMissing] = imputer.transform(data_df[featuresWithMissing]) 
data_df.describe(include = 'all')
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497    6497.000000       6497.000000  6497.000000     6497.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4898            NaN               NaN          NaN             NaN
# mean      NaN       7.216579          0.339691     0.318722        5.444326
# std       NaN       1.295751          0.164548     0.145231        4.757392
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.400000     0.390000        8.100000
# max       NaN      15.900000          1.580000     1.660000       65.800000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count   6497.000000          6497.000000           6497.000000  6497.000000
# unique          NaN                  NaN                   NaN          NaN
# top             NaN                  NaN                   NaN          NaN
# freq            NaN                  NaN                   NaN          NaN
# mean       0.056042            30.525319            115.744574     0.994697
# std        0.035031            17.749400             56.521855     0.002999
# min        0.009000             1.000000              6.000000     0.987110
# 25%        0.038000            17.000000             77.000000     0.992340
# 50%        0.047000            29.000000            118.000000     0.994890
# 75%        0.065000            41.000000            156.000000     0.996990
# max        0.611000           289.000000            440.000000     1.038980
#
#                  pH    sulphates      alcohol      quality
# count   6497.000000  6497.000000  6497.000000  6497.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       3.218395     0.531215    10.491801     5.818378
# std        0.160637     0.148768     1.192712     0.873255
# min        2.720000     0.220000     8.000000     3.000000
# 25%        3.110000     0.430000     9.500000     5.000000
# 50%        3.210000     0.510000    10.300000     6.000000
# 75%        3.320000     0.600000    11.300000     6.000000
# max        4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# I also used ordinal encoding to transform the type feature from string values to integer values.

# %%
fig, ax =plt.subplots(1,3)
plt.subplots_adjust(right=2.5, top=1.5)
sn.boxplot(data_df['residual sugar'], data_df['type'], ax=ax[0])
sn.boxplot(data_df['free sulfur dioxide'], data_df['type'], ax=ax[1])
sn.boxplot(data_df['total sulfur dioxide'], data_df['type'], ax=ax[2])
plt.show()

# %%
#Removing outliers in residual sugar
for i in ['residual sugar','free sulfur dioxide', 'total sulfur dioxide']:
    lower = data_df[i].mean()-3*data_df[i].std()
    upper = data_df[i].mean()+3*data_df[i].std()
    data_df = data_df[(data_df[i]>lower) & (data_df[i]<upper)]

# #Removing outliers in free sulfur dioxide
# lower = data_df['free sulfur dioxide'].mean()-3*data_df['free sulfur dioxide'].std()
# upper = data_df['free sulfur dioxide'].mean()+3*data_df['free sulfur dioxide'].std()
# df = data_df[(data_df['free sulfur dioxide']>lower) & (data_df['free sulfur dioxide']<upper)]

# #Removing outliers in total sulfur dioxide
# lower = data_df['total sulfur dioxide'].mean()-3*df['total sulfur dioxide'].std()
# upper = data_df['total sulfur dioxide'].mean()+3*df['total sulfur dioxide'].std()
# df = data_df[(data_df['total sulfur dioxide']>lower) & (df['total sulfur dioxide']<upper)]

# %%
data_df.describe(include = 'all')
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6430    6430.000000       6430.000000  6430.000000     6430.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4832            NaN               NaN          NaN             NaN
# mean      NaN       7.220562          0.340231     0.318550        5.364726
# std       NaN       1.298764          0.164884     0.144877        4.588666
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.410000     0.390000        8.000000
# max       NaN      15.900000          1.580000     1.660000       19.600000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count   6430.000000          6430.000000           6430.000000  6430.000000
# unique          NaN                  NaN                   NaN          NaN
# top             NaN                  NaN                   NaN          NaN
# freq            NaN                  NaN                   NaN          NaN
# mean       0.056117            30.041291            114.909487     0.994669
# std        0.035170            16.619088             55.840907     0.002923
# min        0.009000             1.000000              6.000000     0.987110
# 25%        0.038000            17.000000             77.000000     0.992320
# 50%        0.047000            29.000000            118.000000     0.994880
# 75%        0.065000            41.000000            155.000000     0.996927
# max        0.611000            83.000000            282.000000     1.003690
#
#                  pH    sulphates      alcohol      quality
# count   6430.000000  6430.000000  6430.000000  6430.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       3.219071     0.531578    10.495914     5.820995
# std        0.160486     0.148807     1.192011     0.870076
# min        2.720000     0.220000     8.000000     3.000000
# 25%        3.110000     0.430000     9.500000     5.000000
# 50%        3.210000     0.510000    10.300000     6.000000
# 75%        3.320000     0.600000    11.300000     6.000000
# max        4.010000     2.000000    14.900000     9.000000

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit(data_df[["type"]])
# enc.categories_
data_df[["type"]] = enc.fit_transform(data_df[["type"]])
data_df.describe(include = 'all')
# Out:
#               type  fixed acidity  volatile acidity  citric acid  \
# count  6430.000000    6430.000000       6430.000000  6430.000000
# mean      0.751477       7.220562          0.340231     0.318550
# std       0.432190       1.298764          0.164884     0.144877
# min       0.000000       3.800000          0.080000     0.000000
# 25%       1.000000       6.400000          0.230000     0.250000
# 50%       1.000000       7.000000          0.290000     0.310000
# 75%       1.000000       7.700000          0.410000     0.390000
# max       1.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     6430.000000  6430.000000          6430.000000           6430.000000
# mean         5.364726     0.056117            30.041291            114.909487
# std          4.588666     0.035170            16.619088             55.840907
# min          0.600000     0.009000             1.000000              6.000000
# 25%          1.800000     0.038000            17.000000             77.000000
# 50%          3.000000     0.047000            29.000000            118.000000
# 75%          8.000000     0.065000            41.000000            155.000000
# max         19.600000     0.611000            83.000000            282.000000
#
#            density           pH    sulphates      alcohol      quality
# count  6430.000000  6430.000000  6430.000000  6430.000000  6430.000000
# mean      0.994669     3.219071     0.531578    10.495914     5.820995
# std       0.002923     0.160486     0.148807     1.192011     0.870076
# min       0.987110     2.720000     0.220000     8.000000     3.000000
# 25%       0.992320     3.110000     0.430000     9.500000     5.000000
# 50%       0.994880     3.210000     0.510000    10.300000     6.000000
# 75%       0.996927     3.320000     0.600000    11.300000     6.000000
# max       1.003690     4.010000     2.000000    14.900000     9.000000

# %%
from sklearn import model_selection
array = data_df.values
# get number of columns
n = array.shape[1] 
X = array[:,0:n-2]
Y = array[:,n-1]
test_size = 0.2
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y,test_size=test_size, random_state=1)

# %%
from keras.utils import to_categorical
Y_train_categorical = to_categorical(Y_train,num_classes=10)
Y_test_categorical = to_categorical(Y_test,num_classes=10)

# %%
scores = []
epochs = range(10, 55, 5)
for epoch in epochs:
    model = tf.keras.models.Sequential()
    # Build the input and the hidden layers
    model.add(tf.keras.layers.Dense(20, activation="relu"))
    model.add(tf.keras.layers.Dense(30, activation="relu"))
    model.add(tf.keras.layers.Dense(20, activation="relu"))
    # Build the output layer
    model.add(tf.keras.layers.Dense(10, activation ="softmax"))
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
    model.fit(x=X_train, y=Y_train_categorical, epochs=epoch) 
    scores.append(model.evaluate(X_test, Y_test_categorical)[1])

plt.plot(n_hidden_unit, scores, marker=None)
plt.xlabel('number of hidden unit per layer')
plt.ylabel('accuracy')

plt.show()

# error = np.count_nonzero(predictions - Y_test)/Y_test.shape[0]
# Out:
# Epoch 1/70
# 161/161 [==============================] - 0s 2ms/step - loss: 2.4437 - accuracy: 0.3235
# Epoch 2/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.3596 - accuracy: 0.4001
# Epoch 3/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.3114 - accuracy: 0.4145
# Epoch 4/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2897 - accuracy: 0.4222
# Epoch 5/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2915 - accuracy: 0.4197
# Epoch 6/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2668 - accuracy: 0.4308
# Epoch 7/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2724 - accuracy: 0.4154
# Epoch 8/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2593 - accuracy: 0.4331
# Epoch 9/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2661 - accuracy: 0.4232
# Epoch 10/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2627 - accuracy: 0.4246
# Epoch 11/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2566 - accuracy: 0.4355
# Epoch 12/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2559 - accuracy: 0.4288
# Epoch 13/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2439 - accuracy: 0.4471
# Epoch 14/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2371 - accuracy: 0.4526
# Epoch 15/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2337 - accuracy: 0.4539
# Epoch 16/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2266 - accuracy: 0.4576
# Epoch 17/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2279 - accuracy: 0.4557
# Epoch 18/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2195 - accuracy: 0.4636
# Epoch 19/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2175 - accuracy: 0.4664
# Epoch 20/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2171 - accuracy: 0.4660
# Epoch 21/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2093 - accuracy: 0.4656
# Epoch 22/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2060 - accuracy: 0.4743
# Epoch 23/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2052 - accuracy: 0.4708
# Epoch 24/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2000 - accuracy: 0.4761
# Epoch 25/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2005 - accuracy: 0.4796
# Epoch 26/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1965 - accuracy: 0.4837
# Epoch 27/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1874 - accuracy: 0.4813
# Epoch 28/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1855 - accuracy: 0.4778
# Epoch 29/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1902 - accuracy: 0.4790
# Epoch 30/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1827 - accuracy: 0.4843
# Epoch 31/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1866 - accuracy: 0.4809
# Epoch 32/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1800 - accuracy: 0.4854
# Epoch 33/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1790 - accuracy: 0.4848
# Epoch 34/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1780 - accuracy: 0.4848
# Epoch 35/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1764 - accuracy: 0.4827
# Epoch 36/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1811 - accuracy: 0.4817
# Epoch 37/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1735 - accuracy: 0.4907
# Epoch 38/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1741 - accuracy: 0.4850
# Epoch 39/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1742 - accuracy: 0.4852
# Epoch 40/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1729 - accuracy: 0.4866
# Epoch 41/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1745 - accuracy: 0.4798
# Epoch 42/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1677 - accuracy: 0.4895
# Epoch 43/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1674 - accuracy: 0.4897
# Epoch 44/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1631 - accuracy: 0.4878
# Epoch 45/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1709 - accuracy: 0.4911
# Epoch 46/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1694 - accuracy: 0.4868
# Epoch 47/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1676 - accuracy: 0.4914
# Epoch 48/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1670 - accuracy: 0.4881
# Epoch 49/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1666 - accuracy: 0.4827
# Epoch 50/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1611 - accuracy: 0.4870
# Epoch 51/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1629 - accuracy: 0.4850
# Epoch 52/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1615 - accuracy: 0.4868
# Epoch 53/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1583 - accuracy: 0.4856
# Epoch 54/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1689 - accuracy: 0.4924
# Epoch 55/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1610 - accuracy: 0.4870
# Epoch 56/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1619 - accuracy: 0.4913
# Epoch 57/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1605 - accuracy: 0.4938
# Epoch 58/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1579 - accuracy: 0.4891
# Epoch 59/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1568 - accuracy: 0.4889
# Epoch 60/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1610 - accuracy: 0.4878
# Epoch 61/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1606 - accuracy: 0.4914
# Epoch 62/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1646 - accuracy: 0.4854
# Epoch 63/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1607 - accuracy: 0.4881
# Epoch 64/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1557 - accuracy: 0.4949
# Epoch 65/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1569 - accuracy: 0.4971
# Epoch 66/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1612 - accuracy: 0.4866
# Epoch 67/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1640 - accuracy: 0.4879
# Epoch 68/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1542 - accuracy: 0.4930
# Epoch 69/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1591 - accuracy: 0.4916
# Epoch 70/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1558 - accuracy: 0.4881
# 41/41 [==============================] - 0s 1ms/step - loss: 1.1900 - accuracy: 0.4844
# Epoch 1/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.8724 - accuracy: 0.3631
# Epoch 2/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.3134 - accuracy: 0.4121
# Epoch 3/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2741 - accuracy: 0.4362
# Epoch 4/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2620 - accuracy: 0.4403
# Epoch 5/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2572 - accuracy: 0.4430
# Epoch 6/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2610 - accuracy: 0.4341
# Epoch 7/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2502 - accuracy: 0.4537
# Epoch 8/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2487 - accuracy: 0.4518
# Epoch 9/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2453 - accuracy: 0.4462
# Epoch 10/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2403 - accuracy: 0.4537
# Epoch 11/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2328 - accuracy: 0.4594
# Epoch 12/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2311 - accuracy: 0.4570
# Epoch 13/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2332 - accuracy: 0.4638
# Epoch 14/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2232 - accuracy: 0.4664
# Epoch 15/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2271 - accuracy: 0.4654
# Epoch 16/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2242 - accuracy: 0.4687
# Epoch 17/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2190 - accuracy: 0.4697
# Epoch 18/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2146 - accuracy: 0.4765
# Epoch 19/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2124 - accuracy: 0.4677
# Epoch 20/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2045 - accuracy: 0.4736
# Epoch 21/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2028 - accuracy: 0.4734
# Epoch 22/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1964 - accuracy: 0.4827
# Epoch 23/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2006 - accuracy: 0.4776
# Epoch 24/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1933 - accuracy: 0.4839
# Epoch 25/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2004 - accuracy: 0.4782
# Epoch 26/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1900 - accuracy: 0.4874
# Epoch 27/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1913 - accuracy: 0.4767
# Epoch 28/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1845 - accuracy: 0.4798
# Epoch 29/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1850 - accuracy: 0.4930
# Epoch 30/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1863 - accuracy: 0.4850
# Epoch 31/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1827 - accuracy: 0.4872
# Epoch 32/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1891 - accuracy: 0.4891
# Epoch 33/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1767 - accuracy: 0.4844
# Epoch 34/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1796 - accuracy: 0.4870
# Epoch 35/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1742 - accuracy: 0.4955
# Epoch 36/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1768 - accuracy: 0.4909
# Epoch 37/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1705 - accuracy: 0.4918
# Epoch 38/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1723 - accuracy: 0.4870
# Epoch 39/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1686 - accuracy: 0.4895
# Epoch 40/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1674 - accuracy: 0.4988
# Epoch 41/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1644 - accuracy: 0.4901
# Epoch 42/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1679 - accuracy: 0.4897
# Epoch 43/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1610 - accuracy: 0.4909
# Epoch 44/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1654 - accuracy: 0.4918
# Epoch 45/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1652 - accuracy: 0.4866
# Epoch 46/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1643 - accuracy: 0.4860
# Epoch 47/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1636 - accuracy: 0.4951
# Epoch 48/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1599 - accuracy: 0.4893
# Epoch 49/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1572 - accuracy: 0.4969
# Epoch 50/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1591 - accuracy: 0.4887
# Epoch 51/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1648 - accuracy: 0.4868
# Epoch 52/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1596 - accuracy: 0.4938
# Epoch 53/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1578 - accuracy: 0.4893
# Epoch 54/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1592 - accuracy: 0.4879
# Epoch 55/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1583 - accuracy: 0.4916
# Epoch 56/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1553 - accuracy: 0.4932
# Epoch 57/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1540 - accuracy: 0.4926
# Epoch 58/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1552 - accuracy: 0.4946
# Epoch 59/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1506 - accuracy: 0.4879
# Epoch 60/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1519 - accuracy: 0.4883
# Epoch 61/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1549 - accuracy: 0.4922
# Epoch 62/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1477 - accuracy: 0.4911
# Epoch 63/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1461 - accuracy: 0.4977
# Epoch 64/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1456 - accuracy: 0.4984
# Epoch 65/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1493 - accuracy: 0.4955
# Epoch 66/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1484 - accuracy: 0.4901
# Epoch 67/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1545 - accuracy: 0.4914
# Epoch 68/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1433 - accuracy: 0.4965
# Epoch 69/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1455 - accuracy: 0.4944
# Epoch 70/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1451 - accuracy: 0.4916
# 41/41 [==============================] - 0s 1ms/step - loss: 1.1808 - accuracy: 0.4697
# Epoch 1/70
# 161/161 [==============================] - 0s 2ms/step - loss: 2.3593 - accuracy: 0.3453
# Epoch 2/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.3114 - accuracy: 0.4137
# Epoch 3/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2826 - accuracy: 0.4322
# Epoch 4/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2676 - accuracy: 0.4384
# Epoch 5/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2583 - accuracy: 0.4454
# Epoch 6/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2473 - accuracy: 0.4539
# Epoch 7/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2497 - accuracy: 0.4539
# Epoch 8/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2398 - accuracy: 0.4578
# Epoch 9/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2344 - accuracy: 0.4607
# Epoch 10/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2359 - accuracy: 0.4598
# Epoch 11/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2356 - accuracy: 0.4551
# Epoch 12/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2334 - accuracy: 0.4710
# Epoch 13/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2177 - accuracy: 0.4730
# Epoch 14/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2158 - accuracy: 0.4636
# Epoch 15/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2110 - accuracy: 0.4724
# Epoch 16/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2071 - accuracy: 0.4761
# Epoch 17/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2059 - accuracy: 0.4811
# Epoch 18/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.2034 - accuracy: 0.4743
# Epoch 19/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1933 - accuracy: 0.4856
# Epoch 20/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1970 - accuracy: 0.4819
# Epoch 21/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1860 - accuracy: 0.4854
# Epoch 22/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1928 - accuracy: 0.4786
# Epoch 23/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1806 - accuracy: 0.4887
# Epoch 24/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1856 - accuracy: 0.4881
# Epoch 25/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1778 - accuracy: 0.4870
# Epoch 26/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1786 - accuracy: 0.4893
# Epoch 27/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1762 - accuracy: 0.4839
# Epoch 28/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1777 - accuracy: 0.4860
# Epoch 29/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1708 - accuracy: 0.4864
# Epoch 30/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1818 - accuracy: 0.4819
# Epoch 31/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1691 - accuracy: 0.4887
# Epoch 32/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1707 - accuracy: 0.4887
# Epoch 33/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1675 - accuracy: 0.4817
# Epoch 34/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1647 - accuracy: 0.4866
# Epoch 35/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1665 - accuracy: 0.4858
# Epoch 36/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1662 - accuracy: 0.4815
# Epoch 37/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1599 - accuracy: 0.4967
# Epoch 38/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1651 - accuracy: 0.4843
# Epoch 39/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1589 - accuracy: 0.4932
# Epoch 40/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1550 - accuracy: 0.4926
# Epoch 41/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1573 - accuracy: 0.4829
# Epoch 42/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1567 - accuracy: 0.4911
# Epoch 43/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1552 - accuracy: 0.4907
# Epoch 44/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1532 - accuracy: 0.4866
# Epoch 45/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1478 - accuracy: 0.4977
# Epoch 46/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1562 - accuracy: 0.4907
# Epoch 47/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1560 - accuracy: 0.4854
# Epoch 48/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1483 - accuracy: 0.4986
# Epoch 49/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1446 - accuracy: 0.4969
# Epoch 50/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1477 - accuracy: 0.4946
# Epoch 51/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1483 - accuracy: 0.5025
# Epoch 52/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1435 - accuracy: 0.5025
# Epoch 53/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1457 - accuracy: 0.4895
# Epoch 54/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1416 - accuracy: 0.4940
# Epoch 55/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1363 - accuracy: 0.5004
# Epoch 56/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1426 - accuracy: 0.4926
# Epoch 57/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1361 - accuracy: 0.4944
# Epoch 58/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1424 - accuracy: 0.4928
# Epoch 59/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1422 - accuracy: 0.4948
# Epoch 60/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1333 - accuracy: 0.4992
# Epoch 61/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1318 - accuracy: 0.5012
# Epoch 62/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1306 - accuracy: 0.4996
# Epoch 63/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1315 - accuracy: 0.4957
# Epoch 64/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1364 - accuracy: 0.4971
# Epoch 65/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1259 - accuracy: 0.5014
# Epoch 66/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1325 - accuracy: 0.4973
# Epoch 67/70
# 161/161 [==============================] - 0s 2ms/step - loss: 1.1313 - accuracy: 0.5029
# Epoch 68/70
#  31/161 [====>.........................] - ETA: 0s - loss: 1.1251 - accuracy: 0.5071
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-01b45b3ae204> in <module>
#      10     model.add(tf.keras.layers.Dense(10, activation ="softmax"))
#      11     model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# ---> 12     model.fit(x=X_train, y=Y_train_categorical, epochs=70)
#      13     scores.append(model.evaluate(X_test, Y_test_categorical)[1])
#      14
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, Y_test_categorical).metrics
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 1.2367 - accuracy: 0.4518
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-beb7a6a6ab01> in <module>
# ----> 1 model.evaluate(X_test, Y_test_categorical).metrics
#
# AttributeError: 'list' object has no attribute 'metrics'

# %% [markdown]
# #### Here we try random forest as a non-DNN method for this task. The hyper parameter we are tuning here is the number of trees used.

# %%
from sklearn.ensemble import RandomForestClassifier
scores = []
n_trees = range(10, 100, 10)
for n in n_trees:
    rfc=RandomForestClassifier(n_estimators=n)
    rfc.fit(X_train,Y_train)
    scores.append(rfc.score(X_test, Y_test))

plt.plot(n_trees, scores, marker=None)
plt.xlabel('number of trees')
plt.ylabel('accuracy')

plt.show()
# Out:
# Accuracy: 65.941%

# %%
rfc=RandomForestClassifier(n_estimators=50)
rfc.fit(X_train,Y_train)
Y_pred = rfc.predict(X_test)
randomForest_confusion_matrix = confusion_matrix(Y_test, Y_pred)
sn.heatmap(randomForest_confusion_matrix, annot=True)
